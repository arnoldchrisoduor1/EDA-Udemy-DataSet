# %% [markdown]
# # EDA Udemy Course Dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\arnol\OneDrive\Desktop\EDA-Udemy-DataSet\udemy_courses.csv",parse_dates=['published_timestamp'])

# %% [markdown]
# ### Top 10 rows in the dataset.

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# ### Bottom 10 rows in the dataset.

# %%
data.tail(10)
# Out:
#       course_id                                       course_title  \
# 3668     270976                             A how to guide in HTML
# 3669     679992                  Building Better APIs with GraphQL
# 3670     330900  Learn Grunt with Examples: Automate Your Front...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3672     865438    jQuery UI in Action: Build 5 jQuery UI Projects
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3668      https://www.udemy.com/a-how-to-guide-in-html/    False      0
# 3669  https://www.udemy.com/building-better-apis-wit...     True     50
# ...

# %% [markdown]
# ### Data information and description.

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
print("The number of columns is: ",data.shape[1])
print("The number of rows is: ", data.shape[0])
# Out:
# The number of columns is:  12
# The number of rows is:  3678

# %% [markdown]
# ### Checking for Duplicates.

# %%
data[data.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
print("The number of rows is: ",data.shape[0])
print("The number of columns is: ",data.shape[1])
# Out:
# The number of rows is:  3672
# The number of columns is:  12

# %% [markdown]
# ### Checking for null values.

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Number of Courses Per Subjects

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
subject_values = data['subject'].value_counts()

plt.figure(figsize=(8,8))
plt.pie(subject_values, labels=subject_values.index, autopct = '%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd519b8c50>,
# ...
#  [Text(-1.0414717836339118, -0.35402898736459243, 'Web Development'),
#   Text(0.7903579733376015, -0.7650714175694184, 'Business Finance'),
#   Text(0.7410652440764602, 0.8129097760649064, 'Musical Instruments'),
#   Text(-0.3850517307180213, 1.0304053399857052, 'Graphic Design')],
#  [Text(-0.56807551834577, -0.19310672038068674, '32.7%'),
#   Text(0.43110434909323714, -0.41731168231059185, '32.4%'),
#   Text(0.40421740585988736, 0.44340533239903984, '18.5%'),
#   Text(-0.21002821675528432, 0.5620392763558391, '16.4%')])

# %% [markdown]
# ### Levels, Udemy Courses Providing The Courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
level_counts = data['level'].value_counts()

plt.figure(figsize = (8, 8))
sns.set(style='whitegrid')
plt.pie(level_counts, labels=level_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd51a11f50>,
# ...
#  [Text(-0.6409167490949853, -0.8939942509488056, 'All Levels'),
#   Text(0.9440454069573667, 0.5646045249576911, 'Beginner Level'),
#   Text(-0.4417287688084602, 1.0074103904600955, 'Intermediate Level'),
#   Text(-0.8065398473511438, 0.7479929642949817, 'Expert Level')],
#  [Text(-0.3495909540518101, -0.48763322779025753, '52.4%'),
#   Text(0.5149338583403819, 0.3079661045223769, '34.5%'),
#   Text(-0.2409429648046146, 0.5494965766145975, '11.5%'),
#   Text(-0.43993082582789655, 0.40799616234271724, '1.6%')])

# %% [markdown]
# ### The Count of Paid and Free Courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
value_counts = data['is_paid'].value_counts()

plt.figure(figsize = (8, 8))
sns.set(style='whitegrid')
plt.pie(value_counts, labels=['Paid', 'Free'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd51a77910>,
# ...
#  [Text(0.627846774622152, -0.9032211399189907, 'Paid'),
#   Text(-0.627846795763568, 0.9032211252231763, 'Free')],
#  [Text(0.3424618770666283, -0.4926660763194494, '91.6%'),
#   Text(-0.3424618885983098, 0.49266606830355064, '8.4%')])

# %% [markdown]
# ###  Course Has More Lectures (Free or Paid)?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
higher_lecs = data.groupby('is_paid')['num_lectures'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=['Paid','Free'], y=higher_lecs)
# Out:
# <Axes: ylabel='num_lectures'>

# %% [markdown]
# ### Higher Number of Subscribers Free or Paid?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
higher_subs = data.groupby('is_paid')['num_subscribers'].sum().sort_values(ascending = False)

# %%
data.groupby('is_paid')['num_subscribers'].sum().sort_values(ascending = False)
# Out:
# is_paid
# True     8140310
# False    3575525
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x='is_paid', y = 'num_subscribers', data=data)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %% [markdown]
# ### Level Has The Highest Number of Subscribers?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('level')['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# level
# All Levels            6871791
# Beginner Level        4051843
# Intermediate Level     742005
# Expert Level            50196
# Name: num_subscribers, dtype: int64

# %%
level_num = data.groupby('level')['num_subscribers'].sum().sort_values(ascending=False)

# %%
sns.barplot(x='level', y='num_subscribers', data=data)
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %% [markdown]
# ### Most Popular Course Title

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['num_subscribers'].max() == data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# ### 10 Most Popular Courses As Per Number of Subscribers

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('course_title')['num_subscribers'].sum().sort_values(ascending=False).head(10)
# Out:
# course_title
# Learn HTML5 Programming From Scratch                          268923
# Coding for Entrepreneurs Basic                                161029
# The Web Developer Bootcamp                                    121584
# Build Your First Website in 1 Week with HTML5 and CSS3        120291
# The Complete Web Developer Course 2.0                         114512
# Free Beginner Electric Guitar Lessons                         101154
# Web Design for Web Developers: Build Beautiful Websites!       98867
# Learn Javascript & JQuery From Scratch                         84897
# Practical PHP: Master the Basics and Code Dynamic Websites     83737
# JavaScript: Understanding the Weird Parts                      79612
# Name: num_subscribers, dtype: int64

# %%
popu = data.groupby('course_title')['num_subscribers'].sum().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(8,8))
ax =sns.barplot(x=popu.index, y=popu)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# Out:
# [Text(0, 0, 'Learn HTML5 Programming From Scratch'),
#  Text(1, 0, 'Coding for Entrepreneurs Basic'),
#  Text(2, 0, 'The Web Developer Bootcamp'),
#  Text(3, 0, 'Build Your First Website in 1 Week with HTML5 and CSS3'),
#  Text(4, 0, 'The Complete Web Developer Course 2.0'),
#  Text(5, 0, 'Free Beginner Electric Guitar Lessons'),
#  Text(6, 0, 'Web Design for Web Developers: Build Beautiful Websites!'),
#  Text(7, 0, 'Learn Javascript & JQuery From Scratch'),
#  Text(8, 0, 'Practical PHP: Master the Basics and Code Dynamic Websites'),
#  Text(9, 0, 'JavaScript: Understanding the Weird Parts')]

# %% [markdown]
# ### Course Which Is Having The Highest Number of Reviews.

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['num_reviews'].max() == data['num_reviews']]['course_title']
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %%
plt.figure(figsize=(10, 4))
sns.barplot(x='subject', y='num_reviews', data=data)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %% [markdown]
# ### Price Affect the Number of Reviews?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.scatterplot(x='price', y='num_reviews', data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# ### Total Number of Courses Related To Python

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
len(data[data['course_title'].str.contains('python', case=False)])
# Out:
# 29

# %% [markdown]
# ### 10 Most Popular Python Courses As Per Number of Subscribers

# %%
python = data[data['course_title'].str.contains('python', case=False, na=False)]. \
sort_values(by='num_subscribers', ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers',y='course_title',data=python)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ### Year The Highest Number of Courses Were Posted?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['Year'] = data['published_timestamp'].dt.year

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
sns.countplot('Year',data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sns.countplot('Year',data=data)
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# ### Category-Wise Count of Posted Subjects [Year Wise]

# %%
data.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
